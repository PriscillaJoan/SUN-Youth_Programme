# %%
import pandas as pd

# %%
next_of_kin = pd.DataFrame({
    "participant_id": ["SUN10002","SUN10004"],  # only minors
    "nok_name": ["Mary Mutoro","Paul Atieno"],
    "nok_phone": ["0712345678","0723456789"]
})

# save next of kin 
next_of_kin.to_csv(r"C:\Users\Admin\Documents\Data Science\practice projects\SUN_Youth_Programme\new_data\next_of_kin.csv", index=False)
print("next_of_kin.csv created successfully!")
# Out:
# next_of_kin.csv created successfully!

# %%
participants_info = pd.DataFrame({
    "participant_id": ["SUN10002","SUN10004","SUN10005","SUN10006","SUN10007","SUN10008","SUN10009"],
    "name": ["Johnson Mutoro","Grace Atieno","Purity Akinyi","Louiza Amimo","Benson Kigera","Yvonne Lilly","Frank Kiptoo"],
    "phone": ["712222333","722456754","788765789","726780700","254735000000","780345678","723546768"],
    "age": [15,14,33,28,26,35,22],
    "gender": ["Male","Female","Female","Female","Male","Female","Male"],
    "attendance": ["Present","Absent","Present","Absent","Absent","Present","Present"],
    "session_date": ["11/5/2025","11/12/2025","11/19/2025","11/19/2025","11/26/2025","11/26/2025","12/2/2025"],
    "session_topic": ["Introduction to Computers","Basic Typing Skills","Basic Typing Skills","Digital Creativity","Digital Creativity","Communication Skills","Communication Skills"],
    "reason_for_absence": ["", "Sick", "", "Travel", "Personal", "", ""],
    "education_level": ["Secondary","Primary","Tertiary","Tertiary","Secondary","Tertiary","Secondary"],
    "occupation": ["", "", "Cook", "Hawker", "Driver", "House Keeper", "Vendor"],  # occupation is  only for the adults
    "villages": ["Laini Saba", "Makina", "Kisumu Ndogo", "Gatwekera", "Laini Saba", "Makina", "Kisumu Ndogo"]  })

# save participants info
participants_info.to_csv(r"C:\Users\Admin\Documents\Data Science\practice projects\SUN_Youth_Programme\new_data\participants_info.csv", index=False)
print("participants_info.csv created successfully!")
# Out:
# participants_info.csv created successfully!

# %%
participants_performance_metrics =pd.DataFrame({ "pre_assessment_score": [40, 35, 60, 50, 45, 70, 55],
    "post_assessment_score": [70, 60, 85, 75, 65, 90, 80], 
"pre_confidence_level": ["Beginner", "Beginner", "Intermediate", "Intermediate", "Beginner", "Intermediate", "Intermediate"]})

# save participants info
participants_performance_metrics.to_csv(r"C:\Users\Admin\Documents\Data Science\practice projects\SUN_Youth_Programme\new_data\participants_performance_metric.csv", index=False)
print("participants_performance_metric.csv created successfully!")
# Out:
# participants_performance_metric.csv created successfully!
